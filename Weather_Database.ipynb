# %%
# Import dependencies.
import pandas as pd
import numpy as np
from citipy import citipy
# Import the API key.
from config import weather_api_key
# Import the requests library.
import requests

## Imports that we used in the modules, but were not needed for this deliverable.
# import matplotlib.pyplot as plt
# Import the time module.
# import time
# Import the datetime module from the datetime library.
# from datetime import datetime
# Import linear regression from the SciPy stats module.
# from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
    #group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
    #log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_dc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | provideniya
# Processing Record 3 of Set 1 | himare
# Processing Record 4 of Set 1 | moose factory
# Processing Record 5 of Set 1 | kununurra
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 1 | east london
# Processing Record 9 of Set 1 | vizinga
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | saint george
# Processing Record 12 of Set 1 | port elizabeth
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | inhambane
# Processing Record 17 of Set 1 | mount gambier
# Processing Record 18 of Set 1 | soldotna
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | myre
# Processing Record 22 of Set 1 | broome
# Processing Record 23 of Set 1 | murakami
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | albany
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | kungurtug
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | brandon
# Processing Record 30 of Set 1 | severo-kurilsk
# Processing Record 31 of Set 1 | fortuna
# Processing Record 32 of Set 1 | itoman
# Processing Record 33 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | nemuro
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | kampot
# Processing Record 38 of Set 1 | namatanai
# Processing Record 39 of Set 1 | san quintin
# Processing Record 40 of Set 1 | port augusta
# Processing Record 41 of Set 1 | jacareacanga
# Processing Record 42 of Set 1 | ileza
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | vinh
# Processing Record 45 of Set 1 | soyo
# Processing Record 46 of Set 1 | qasigiannguit
# Processing Record 47 of Set 1 | muskegon
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | luganville
# Processing Record 50 of Set 1 | pevek
# Processing Record 1 of Set 2 | buckingham
# Processing Record 2 of Set 2 | narsaq
# Processing Record 3 of Set 2 | lagoa
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | ribeira grande
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | castro
# Processing Record 10 of Set 2 | lompoc
# Processing Record 11 of Set 2 | muhos
# Processing Record 12 of Set 2 | aliwal north
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | guerrero negro
# Processing Record 16 of Set 2 | mirnyy
# Processing Record 17 of Set 2 | hithadhoo
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | puerto ayora
# Processing Record 20 of Set 2 | sao filipe
# Processing Record 21 of Set 2 | san andres
# Processing Record 22 of Set 2 | savannakhet
# Processing Record 23 of Set 2 | meulaboh
# Processing Record 24 of Set 2 | norman wells
# Processing Record 25 of Set 2 | santa rosa
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | odweyne
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | sembe
# Processing Record 30 of Set 2 | talnakh
# Processing Record 31 of Set 2 | stokmarknes
# Processing Record 32 of Set 2 | coihaique
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | kerema
# Processing Record 35 of Set 2 | jadu
# Processing Record 36 of Set 2 | richards bay
# Processing Record 37 of Set 2 | saint-philippe
# Processing Record 38 of Set 2 | mvuma
# Processing Record 39 of Set 2 | bethel
# Processing Record 40 of Set 2 | san cristobal
# Processing Record 41 of Set 2 | port hardy
# Processing Record 42 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 2 | college place
# Processing Record 44 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 2 | baneh
# Processing Record 46 of Set 2 | milford
# Processing Record 47 of Set 2 | halifax
# Processing Record 48 of Set 2 | kloulklubed
# Processing Record 49 of Set 2 | sinnamary
# Processing Record 50 of Set 2 | airai
# Processing Record 1 of Set 3 | kapaa
# Processing Record 2 of Set 3 | clonakilty
# Processing Record 3 of Set 3 | atar
# Processing Record 4 of Set 3 | lerwick
# Processing Record 5 of Set 3 | srednekolymsk
# Processing Record 6 of Set 3 | nome
# Processing Record 7 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | san ramon
# Processing Record 10 of Set 3 | hammerfest
# Processing Record 11 of Set 3 | nikolskoye
# Processing Record 12 of Set 3 | avarua
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | vrangel
# Processing Record 15 of Set 3 | bull savanna
# Processing Record 16 of Set 3 | kavaratti
# Processing Record 17 of Set 3 | ziyang
# Processing Record 18 of Set 3 | vardo
# Processing Record 19 of Set 3 | kamaishi
# Processing Record 20 of Set 3 | kaitangata
# Processing Record 21 of Set 3 | balikpapan
# Processing Record 22 of Set 3 | rudbar
# Processing Record 23 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | santa maria
# Processing Record 27 of Set 3 | caravelas
# Processing Record 28 of Set 3 | belaya gora
# Processing Record 29 of Set 3 | harper
# Processing Record 30 of Set 3 | pacific grove
# Processing Record 31 of Set 3 | paucartambo
# City not found. Skipping...
# Processing Record 32 of Set 3 | beloha
# Processing Record 33 of Set 3 | vaini
# Processing Record 34 of Set 3 | fatehpur
# Processing Record 35 of Set 3 | saint-francois
# Processing Record 36 of Set 3 | otanche
# Processing Record 37 of Set 3 | nabire
# Processing Record 38 of Set 3 | mabaruma
# Processing Record 39 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 3 | ilulissat
# Processing Record 42 of Set 3 | yellowknife
# Processing Record 43 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 3 | kefamenanu
# Processing Record 45 of Set 3 | batticaloa
# Processing Record 46 of Set 3 | lebu
# Processing Record 47 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 3 | nanakuli
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | ketchikan
# Processing Record 1 of Set 4 | codrington
# Processing Record 2 of Set 4 | lima
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | cabra
# Processing Record 5 of Set 4 | matamoros
# Processing Record 6 of Set 4 | litoral del san juan
# City not found. Skipping...
# Processing Record 7 of Set 4 | bonthe
# Processing Record 8 of Set 4 | cayenne
# Processing Record 9 of Set 4 | mandera
# Processing Record 10 of Set 4 | te anau
# Processing Record 11 of Set 4 | barrow
# Processing Record 12 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 4 | iqaluit
# Processing Record 14 of Set 4 | sao jose da coroa grande
# Processing Record 15 of Set 4 | mayumba
# Processing Record 16 of Set 4 | gravdal
# Processing Record 17 of Set 4 | mahibadhoo
# Processing Record 18 of Set 4 | manuk mangkaw
# Processing Record 19 of Set 4 | ous
# Processing Record 20 of Set 4 | borogontsy
# Processing Record 21 of Set 4 | grants
# Processing Record 22 of Set 4 | houma
# Processing Record 23 of Set 4 | gabu
# Processing Record 24 of Set 4 | lianran
# Processing Record 25 of Set 4 | krymsk
# Processing Record 26 of Set 4 | klyuchi
# Processing Record 27 of Set 4 | nchelenge
# Processing Record 28 of Set 4 | bagdarin
# Processing Record 29 of Set 4 | adre
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | zalalovo
# Processing Record 32 of Set 4 | upernavik
# Processing Record 33 of Set 4 | mersing
# Processing Record 34 of Set 4 | katsuura
# Processing Record 35 of Set 4 | cabildo
# Processing Record 36 of Set 4 | esperance
# Processing Record 37 of Set 4 | santa lucia
# Processing Record 38 of Set 4 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 39 of Set 4 | pokaran
# Processing Record 40 of Set 4 | port lincoln
# Processing Record 41 of Set 4 | bathsheba
# Processing Record 42 of Set 4 | chuy
# Processing Record 43 of Set 4 | mount isa
# Processing Record 44 of Set 4 | dingle
# Processing Record 45 of Set 4 | witbank
# Processing Record 46 of Set 4 | daitari
# Processing Record 47 of Set 4 | qaanaaq
# Processing Record 48 of Set 4 | samarai
# Processing Record 49 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 50 of Set 4 | nanortalik
# Processing Record 1 of Set 5 | nokaneng
# Processing Record 2 of Set 5 | russell
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | port hedland
# Processing Record 5 of Set 5 | fukue
# Processing Record 6 of Set 5 | vostok
# Processing Record 7 of Set 5 | havre-saint-pierre
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | cockburn town
# Processing Record 10 of Set 5 | clarence town
# Processing Record 11 of Set 5 | hailar
# Processing Record 12 of Set 5 | felidhoo
# City not found. Skipping...
# Processing Record 13 of Set 5 | livingston
# Processing Record 14 of Set 5 | faya
# Processing Record 15 of Set 5 | camacha
# Processing Record 16 of Set 5 | nizhniy tsasuchey
# Processing Record 17 of Set 5 | kodiak
# Processing Record 18 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 5 | uncia
# Processing Record 20 of Set 5 | sorland
# Processing Record 21 of Set 5 | tezu
# Processing Record 22 of Set 5 | sitka
# Processing Record 23 of Set 5 | koulikoro
# Processing Record 24 of Set 5 | kasempa
# Processing Record 25 of Set 5 | tapes
# Processing Record 26 of Set 5 | marsaxlokk
# Processing Record 27 of Set 5 | nisia floresta
# Processing Record 28 of Set 5 | taoudenni
# Processing Record 29 of Set 5 | szczytno
# Processing Record 30 of Set 5 | sur
# Processing Record 31 of Set 5 | tasiilaq
# Processing Record 32 of Set 5 | banda aceh
# Processing Record 33 of Set 5 | kirakira
# Processing Record 34 of Set 5 | arraial do cabo
# Processing Record 35 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 5 | shaki
# Processing Record 37 of Set 5 | cherskiy
# Processing Record 38 of Set 5 | vao
# Processing Record 39 of Set 5 | mishelevka
# Processing Record 40 of Set 5 | conde
# Processing Record 41 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 42 of Set 5 | lavra
# Processing Record 43 of Set 5 | tual
# Processing Record 44 of Set 5 | qaqortoq
# Processing Record 45 of Set 5 | beipiao
# Processing Record 46 of Set 5 | calabozo
# Processing Record 47 of Set 5 | ponta do sol
# Processing Record 48 of Set 5 | constitucion
# Processing Record 49 of Set 5 | henties bay
# Processing Record 50 of Set 5 | tilichiki
# Processing Record 1 of Set 6 | husavik
# Processing Record 2 of Set 6 | xiaoweizhai
# Processing Record 3 of Set 6 | shaunavon
# Processing Record 4 of Set 6 | killybegs
# Processing Record 5 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 6 of Set 6 | muros
# Processing Record 7 of Set 6 | filimonovo
# Processing Record 8 of Set 6 | gainesville
# Processing Record 9 of Set 6 | morondava
# Processing Record 10 of Set 6 | alcantara
# Processing Record 11 of Set 6 | kurduvadi
# Processing Record 12 of Set 6 | faanui
# Processing Record 13 of Set 6 | saskylakh
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | tommot
# Processing Record 16 of Set 6 | monrovia
# Processing Record 17 of Set 6 | xadani
# City not found. Skipping...
# Processing Record 18 of Set 6 | guozhen
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | touros
# Processing Record 21 of Set 6 | roebourne
# Processing Record 22 of Set 6 | marawi
# Processing Record 23 of Set 6 | la ronge
# Processing Record 24 of Set 6 | mirador
# Processing Record 25 of Set 6 | ribas do rio pardo
# Processing Record 26 of Set 6 | los llanos de aridane
# Processing Record 27 of Set 6 | kubuta
# Processing Record 28 of Set 6 | linxia
# Processing Record 29 of Set 6 | fairbanks
# Processing Record 30 of Set 6 | pisco
# Processing Record 31 of Set 6 | canon city
# Processing Record 32 of Set 6 | clyde river
# Processing Record 33 of Set 6 | gat
# Processing Record 34 of Set 6 | sukhumi
# Processing Record 35 of Set 6 | vila franca do campo
# Processing Record 36 of Set 6 | zhigansk
# Processing Record 37 of Set 6 | chokurdakh
# Processing Record 38 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 39 of Set 6 | marienburg
# Processing Record 40 of Set 6 | aksarka
# Processing Record 41 of Set 6 | santa cruz de tenerife
# Processing Record 42 of Set 6 | diamantino
# Processing Record 43 of Set 6 | bambous virieux
# Processing Record 44 of Set 6 | klaksvik
# Processing Record 45 of Set 6 | sibolga
# Processing Record 46 of Set 6 | athabasca
# Processing Record 47 of Set 6 | souillac
# Processing Record 48 of Set 6 | san juan
# Processing Record 49 of Set 6 | saint anthony
# Processing Record 50 of Set 6 | ambon
# Processing Record 1 of Set 7 | valparaiso
# Processing Record 2 of Set 7 | comodoro rivadavia
# Processing Record 3 of Set 7 | kuusamo
# Processing Record 4 of Set 7 | westpunt
# City not found. Skipping...
# Processing Record 5 of Set 7 | saint-donat-de-montcalm
# Processing Record 6 of Set 7 | emerald
# Processing Record 7 of Set 7 | serafimovich
# Processing Record 8 of Set 7 | adrar
# Processing Record 9 of Set 7 | hofn
# Processing Record 10 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 7 | presidente medici
# Processing Record 12 of Set 7 | kalisz
# Processing Record 13 of Set 7 | iquitos
# Processing Record 14 of Set 7 | saldanha
# Processing Record 15 of Set 7 | khatanga
# Processing Record 16 of Set 7 | raudeberg
# Processing Record 17 of Set 7 | saint-pierre
# Processing Record 18 of Set 7 | hukeri
# Processing Record 19 of Set 7 | dubbo
# Processing Record 20 of Set 7 | urucui
# Processing Record 21 of Set 7 | christchurch
# Processing Record 22 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 23 of Set 7 | soe
# Processing Record 24 of Set 7 | chicama
# Processing Record 25 of Set 7 | birao
# Processing Record 26 of Set 7 | saint-felicien
# Processing Record 27 of Set 7 | diffa
# Processing Record 28 of Set 7 | romitan
# Processing Record 29 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 7 | castelo do piaui
# Processing Record 31 of Set 7 | ensley
# Processing Record 32 of Set 7 | culleredo
# Processing Record 33 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 7 | alice springs
# Processing Record 35 of Set 7 | sontra
# Processing Record 36 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 37 of Set 7 | lavrentiya
# Processing Record 38 of Set 7 | tuatapere
# Processing Record 39 of Set 7 | xiuyan
# Processing Record 40 of Set 7 | timmins
# Processing Record 41 of Set 7 | itaituba
# Processing Record 42 of Set 7 | salalah
# Processing Record 43 of Set 7 | pahrump
# Processing Record 44 of Set 7 | diu
# Processing Record 45 of Set 7 | rubiataba
# Processing Record 46 of Set 7 | bandarbeyla
# Processing Record 47 of Set 7 | dembi dolo
# Processing Record 48 of Set 7 | guider
# Processing Record 49 of Set 7 | mandalgovi
# Processing Record 50 of Set 7 | kudahuvadhoo
# Processing Record 1 of Set 8 | maragogi
# Processing Record 2 of Set 8 | saryozek
# Processing Record 3 of Set 8 | popondetta
# Processing Record 4 of Set 8 | otacilio costa
# Processing Record 5 of Set 8 | traverse city
# Processing Record 6 of Set 8 | khor
# Processing Record 7 of Set 8 | tahoua
# Processing Record 8 of Set 8 | tessalit
# Processing Record 9 of Set 8 | cedar city
# Processing Record 10 of Set 8 | awjilah
# Processing Record 11 of Set 8 | aykhal
# Processing Record 12 of Set 8 | gorontalo
# Processing Record 13 of Set 8 | buraydah
# Processing Record 14 of Set 8 | marzuq
# Processing Record 15 of Set 8 | huilong
# Processing Record 16 of Set 8 | buala
# Processing Record 17 of Set 8 | yar-sale
# Processing Record 18 of Set 8 | la tuque
# Processing Record 19 of Set 8 | mahebourg
# Processing Record 20 of Set 8 | akdepe
# Processing Record 21 of Set 8 | kosa
# Processing Record 22 of Set 8 | palmer
# Processing Record 23 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 8 | baoning
# Processing Record 25 of Set 8 | sazava
# Processing Record 26 of Set 8 | alofi
# Processing Record 27 of Set 8 | tonantins
# Processing Record 28 of Set 8 | tombouctou
# Processing Record 29 of Set 8 | aswan
# Processing Record 30 of Set 8 | saint-prosper
# Processing Record 31 of Set 8 | padang
# Processing Record 32 of Set 8 | charlestown
# Processing Record 33 of Set 8 | polunochnoye
# Processing Record 34 of Set 8 | santa ana
# Processing Record 35 of Set 8 | tiksi
# Processing Record 36 of Set 8 | ouargaye
# Processing Record 37 of Set 8 | porto santo
# Processing Record 38 of Set 8 | pedernales
# Processing Record 39 of Set 8 | mezen
# Processing Record 40 of Set 8 | canto do buriti
# Processing Record 41 of Set 8 | nhulunbuy
# Processing Record 42 of Set 8 | san
# Processing Record 43 of Set 8 | saint-joseph
# Processing Record 44 of Set 8 | amga
# Processing Record 45 of Set 8 | hamilton
# Processing Record 46 of Set 8 | vestmannaeyjar
# Processing Record 47 of Set 8 | galiakot
# Processing Record 48 of Set 8 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 8 | bosaso
# Processing Record 50 of Set 8 | el zapote
# Processing Record 1 of Set 9 | la palma
# Processing Record 2 of Set 9 | rawson
# Processing Record 3 of Set 9 | axim
# Processing Record 4 of Set 9 | praya
# Processing Record 5 of Set 9 | iranshahr
# Processing Record 6 of Set 9 | rabo de peixe
# Processing Record 7 of Set 9 | antofagasta
# Processing Record 8 of Set 9 | yuzhno-kurilsk
# Processing Record 9 of Set 9 | tongren
# Processing Record 10 of Set 9 | xai-xai
# Processing Record 11 of Set 9 | lata
# Processing Record 12 of Set 9 | abashiri
# Processing Record 13 of Set 9 | svetlyy
# Processing Record 14 of Set 9 | eyl
# Processing Record 15 of Set 9 | malente
# Processing Record 16 of Set 9 | moerai
# Processing Record 17 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 9 | phuket
# Processing Record 19 of Set 9 | angoche
# Processing Record 20 of Set 9 | fare
# Processing Record 21 of Set 9 | ormara
# Processing Record 22 of Set 9 | ugoofaaru
# Processing Record 23 of Set 9 | vangaindrano
# Processing Record 24 of Set 9 | linfen
# Processing Record 25 of Set 9 | margate
# Processing Record 26 of Set 9 | mujiayingzi
# Processing Record 27 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | palm harbor
# Processing Record 29 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 30 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 9 | palauig
# Processing Record 32 of Set 9 | ambovombe
# Processing Record 33 of Set 9 | grand-santi
# Processing Record 34 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 35 of Set 9 | hannibal
# Processing Record 36 of Set 9 | baley
# Processing Record 37 of Set 9 | abu samrah
# Processing Record 38 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 39 of Set 9 | goderich
# Processing Record 40 of Set 9 | kruisfontein
# Processing Record 41 of Set 9 | egvekinot
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 9 | baton rouge
# Processing Record 45 of Set 9 | uray
# Processing Record 46 of Set 9 | kaka
# Processing Record 47 of Set 9 | rundu
# Processing Record 48 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 49 of Set 9 | xuddur
# Processing Record 50 of Set 9 | ahipara
# Processing Record 1 of Set 10 | antalaha
# Processing Record 2 of Set 10 | yuancheng
# Processing Record 3 of Set 10 | kharp
# Processing Record 4 of Set 10 | shache
# Processing Record 5 of Set 10 | nobres
# Processing Record 6 of Set 10 | seguela
# Processing Record 7 of Set 10 | pouembout
# Processing Record 8 of Set 10 | eirunepe
# Processing Record 9 of Set 10 | brae
# Processing Record 10 of Set 10 | hambantota
# Processing Record 11 of Set 10 | srednyaya akhtuba
# Processing Record 12 of Set 10 | yumen
# Processing Record 13 of Set 10 | road town
# Processing Record 14 of Set 10 | sobolevo
# Processing Record 15 of Set 10 | diego de almagro
# Processing Record 16 of Set 10 | stolin
# Processing Record 17 of Set 10 | bara
# Processing Record 18 of Set 10 | naze
# Processing Record 19 of Set 10 | premnitz
# Processing Record 20 of Set 10 | high rock
# Processing Record 21 of Set 10 | acapulco
# Processing Record 22 of Set 10 | beringovskiy
# Processing Record 23 of Set 10 | mandiana
# Processing Record 24 of Set 10 | goba
# Processing Record 25 of Set 10 | pangobilian
# Processing Record 26 of Set 10 | deputatskiy
# Processing Record 27 of Set 10 | makakilo city
# Processing Record 28 of Set 10 | barra do garcas
# Processing Record 29 of Set 10 | the valley
# Processing Record 30 of Set 10 | requena
# Processing Record 31 of Set 10 | aklavik
# Processing Record 32 of Set 10 | mikkeli
# Processing Record 33 of Set 10 | carora
# Processing Record 34 of Set 10 | tevaitoa
# Processing Record 35 of Set 10 | pochutla
# Processing Record 36 of Set 10 | turukhansk
# Processing Record 37 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 38 of Set 10 | ekhabi
# Processing Record 39 of Set 10 | hami
# Processing Record 40 of Set 10 | sazonovo
# Processing Record 41 of Set 10 | berekum
# Processing Record 42 of Set 10 | mareeba
# Processing Record 43 of Set 10 | ruatoria
# City not found. Skipping...
# Processing Record 44 of Set 10 | port blair
# Processing Record 45 of Set 10 | mozarlandia
# Processing Record 46 of Set 10 | longyan
# Processing Record 47 of Set 10 | qui nhon
# Processing Record 48 of Set 10 | manitouwadge
# Processing Record 49 of Set 10 | menongue
# Processing Record 50 of Set 10 | katha
# City not found. Skipping...
# Processing Record 1 of Set 11 | uglich
# Processing Record 2 of Set 11 | basco
# Processing Record 3 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 11 | paamiut
# Processing Record 5 of Set 11 | asfi
# Processing Record 6 of Set 11 | leningradskiy
# Processing Record 7 of Set 11 | astoria
# Processing Record 8 of Set 11 | tiznit
# Processing Record 9 of Set 11 | grindavik
# Processing Record 10 of Set 11 | saint-augustin
# Processing Record 11 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 11 | north platte
# Processing Record 14 of Set 11 | bakel
# Processing Record 15 of Set 11 | mansehra
# Processing Record 16 of Set 11 | astipalaia
# City not found. Skipping...
# Processing Record 17 of Set 11 | lakhdenpokhya
# Processing Record 18 of Set 11 | sadiqabad
# Processing Record 19 of Set 11 | kisangani
# Processing Record 20 of Set 11 | gamba
# Processing Record 21 of Set 11 | bonavista
# Processing Record 22 of Set 11 | nadvoitsy
# Processing Record 23 of Set 11 | southwick
# Processing Record 24 of Set 11 | noumea
# Processing Record 25 of Set 11 | namalenga
# Processing Record 26 of Set 11 | rio cuarto
# Processing Record 27 of Set 11 | sistranda
# Processing Record 28 of Set 11 | sakakah
# Processing Record 29 of Set 11 | fuerte olimpo
# Processing Record 30 of Set 11 | atocha
# Processing Record 31 of Set 11 | loukhi
# Processing Record 32 of Set 11 | west wendover
# Processing Record 33 of Set 11 | riyadh
# Processing Record 34 of Set 11 | teya
# Processing Record 35 of Set 11 | rantepao
# Processing Record 36 of Set 11 | yabrud
# Processing Record 37 of Set 11 | anito
# Processing Record 38 of Set 11 | ternovka
# Processing Record 39 of Set 11 | luanda
# Processing Record 40 of Set 11 | byron bay
# Processing Record 41 of Set 11 | seymchan
# Processing Record 42 of Set 11 | krivosheino
# Processing Record 43 of Set 11 | laguna
# Processing Record 44 of Set 11 | berlevag
# Processing Record 45 of Set 11 | khatra
# Processing Record 46 of Set 11 | taksimo
# Processing Record 47 of Set 11 | tanete
# Processing Record 48 of Set 11 | yulara
# Processing Record 49 of Set 11 | labuhan
# Processing Record 50 of Set 11 | changji
# Processing Record 1 of Set 12 | vanavara
# Processing Record 2 of Set 12 | eidfjord
# Processing Record 3 of Set 12 | mangaratiba
# Processing Record 4 of Set 12 | havoysund
# Processing Record 5 of Set 12 | kalat
# Processing Record 6 of Set 12 | avera
# Processing Record 7 of Set 12 | kytlym
# City not found. Skipping...
# Processing Record 8 of Set 12 | plouzane
# Processing Record 9 of Set 12 | bubaque
# Processing Record 10 of Set 12 | hvolsvollur
# Processing Record 11 of Set 12 | george
# Processing Record 12 of Set 12 | ust-tsilma
# Processing Record 13 of Set 12 | umm kaddadah
# Processing Record 14 of Set 12 | lidkoping
# Processing Record 15 of Set 12 | ozernovskiy
# Processing Record 16 of Set 12 | yining
# Processing Record 17 of Set 12 | knokke-heist
# Processing Record 18 of Set 12 | kayes
# Processing Record 19 of Set 12 | florida
# Processing Record 20 of Set 12 | alamogordo
# Processing Record 21 of Set 12 | kurumkan
# Processing Record 22 of Set 12 | asau
# Processing Record 23 of Set 12 | camargo
# Processing Record 24 of Set 12 | rio grande
# Processing Record 25 of Set 12 | topeka
# Processing Record 26 of Set 12 | danville
# Processing Record 27 of Set 12 | healdsburg
# Processing Record 28 of Set 12 | wilmington
# Processing Record 29 of Set 12 | poum
# Processing Record 30 of Set 12 | verkhnetulomskiy
# Processing Record 31 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 32 of Set 12 | port macquarie
# Processing Record 33 of Set 12 | camopi
# Processing Record 34 of Set 12 | erzin
# Processing Record 35 of Set 12 | bowen
# Processing Record 36 of Set 12 | molochnoye
# Processing Record 37 of Set 12 | bossembele
# City not found. Skipping...
# Processing Record 38 of Set 12 | tura
# Processing Record 39 of Set 12 | srandakan
# Processing Record 40 of Set 12 | kihei
# Processing Record 41 of Set 12 | hasaki
# Processing Record 42 of Set 12 | lagos
# Processing Record 43 of Set 12 | asyut
# Processing Record 44 of Set 12 | sibenik
# Processing Record 45 of Set 12 | roald
# Processing Record 46 of Set 12 | westport
# Processing Record 47 of Set 12 | arbagar
# Processing Record 48 of Set 12 | boyolangu
# Processing Record 49 of Set 12 | kusye-aleksandrovskiy
# City not found. Skipping...
# Processing Record 50 of Set 12 | paita
# Processing Record 1 of Set 13 | vuktyl
# Processing Record 2 of Set 13 | coquimbo
# Processing Record 3 of Set 13 | haapiti
# Processing Record 4 of Set 13 | thayetmyo
# Processing Record 5 of Set 13 | monforte de lemos
# Processing Record 6 of Set 13 | sal rei
# Processing Record 7 of Set 13 | chikwawa
# Processing Record 8 of Set 13 | chivacoa
# Processing Record 9 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 10 of Set 13 | la paz
# Processing Record 11 of Set 13 | orapa
# Processing Record 12 of Set 13 | silver city
# Processing Record 13 of Set 13 | sioux lookout
# Processing Record 14 of Set 13 | oksfjord
# Processing Record 15 of Set 13 | sao felix do xingu
# Processing Record 16 of Set 13 | pangnirtung
# Processing Record 17 of Set 13 | taltal
# Processing Record 18 of Set 13 | kologriv
# Processing Record 19 of Set 13 | jalingo
# Processing Record 20 of Set 13 | salmas
# Processing Record 21 of Set 13 | korla
# Processing Record 22 of Set 13 | vallee-jonction
# City not found. Skipping...
# Processing Record 23 of Set 13 | morros
# Processing Record 24 of Set 13 | staunton
# Processing Record 25 of Set 13 | voh
# Processing Record 26 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 13 | puerto suarez
# Processing Record 28 of Set 13 | rosetown
# Processing Record 29 of Set 13 | hervey bay
# Processing Record 30 of Set 13 | orocue
# Processing Record 31 of Set 13 | mackay
# Processing Record 32 of Set 13 | gladstone
# Processing Record 33 of Set 13 | pershotravneve
# Processing Record 34 of Set 13 | ilhabela
# Processing Record 35 of Set 13 | daud khel
# Processing Record 36 of Set 13 | ndola
# Processing Record 37 of Set 13 | lashio
# Processing Record 38 of Set 13 | vila do maio
# Processing Record 39 of Set 13 | sao joao da barra
# Processing Record 40 of Set 13 | dali
# Processing Record 41 of Set 13 | missoula
# Processing Record 42 of Set 13 | asosa
# Processing Record 43 of Set 13 | leh
# Processing Record 44 of Set 13 | sudova vyshnya
# Processing Record 45 of Set 13 | takoradi
# Processing Record 46 of Set 13 | mahon
# Processing Record 47 of Set 13 | benghazi
# Processing Record 48 of Set 13 | necochea
# Processing Record 49 of Set 13 | casablanca
# Processing Record 50 of Set 13 | tabuk
# Processing Record 1 of Set 14 | moron
# Processing Record 2 of Set 14 | zarubino
# Processing Record 3 of Set 14 | kamenka
# Processing Record 4 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 5 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 14 | valley city
# Processing Record 7 of Set 14 | san carlos
# Processing Record 8 of Set 14 | umm jarr
# City not found. Skipping...
# Processing Record 9 of Set 14 | waddan
# Processing Record 10 of Set 14 | jalu
# Processing Record 11 of Set 14 | whitehorse
# Processing Record 12 of Set 14 | bogatyye saby
# Processing Record 13 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 14 of Set 14 | dakar
# Processing Record 15 of Set 14 | zavidovici
# Processing Record 16 of Set 14 | sola
# Processing Record 17 of Set 14 | griffith
# Processing Record 18 of Set 14 | aksu
# Processing Record 19 of Set 14 | golden
# Processing Record 20 of Set 14 | enshi
# Processing Record 21 of Set 14 | tiarei
# Processing Record 22 of Set 14 | chota
# Processing Record 23 of Set 14 | hadgaon
# Processing Record 24 of Set 14 | poronaysk
# Processing Record 25 of Set 14 | guanica
# Processing Record 26 of Set 14 | karaman
# Processing Record 27 of Set 14 | cangzhou
# Processing Record 28 of Set 14 | wanning
# Processing Record 29 of Set 14 | surazh
# Processing Record 30 of Set 14 | mayor pablo lagerenza
# Processing Record 31 of Set 14 | tromso
# Processing Record 32 of Set 14 | jabinyanah
# Processing Record 33 of Set 14 | pishin
# Processing Record 34 of Set 14 | faridpur
# Processing Record 35 of Set 14 | mildura
# Processing Record 36 of Set 14 | tikapur
# Processing Record 37 of Set 14 | ondjiva
# Processing Record 38 of Set 14 | kendari
# Processing Record 39 of Set 14 | kolosovka
# Processing Record 40 of Set 14 | cabo san lucas
# Processing Record 41 of Set 14 | warrington
# Processing Record 42 of Set 14 | ossora
# Processing Record 43 of Set 14 | koszalin
# Processing Record 44 of Set 14 | araouane
# Processing Record 45 of Set 14 | ancud
# Processing Record 46 of Set 14 | namibe
# Processing Record 47 of Set 14 | kudymkar
# Processing Record 48 of Set 14 | ocos
# Processing Record 49 of Set 14 | ruteng
# Processing Record 50 of Set 14 | kasongo-lunda
# Processing Record 1 of Set 15 | zhanaozen
# Processing Record 2 of Set 15 | kuah
# Processing Record 3 of Set 15 | curuca
# Processing Record 4 of Set 15 | tabas
# Processing Record 5 of Set 15 | montepuez
# Processing Record 6 of Set 15 | rutana
# Processing Record 7 of Set 15 | salamiyah
# Processing Record 8 of Set 15 | gazanjyk
# Processing Record 9 of Set 15 | santiago
# Processing Record 10 of Set 15 | kotelnikovo
# Processing Record 11 of Set 15 | umm lajj
# Processing Record 12 of Set 15 | soderhamn
# Processing Record 13 of Set 15 | kelapa sawit
# Processing Record 14 of Set 15 | jiexiu
# Processing Record 15 of Set 15 | muyezerskiy
# Processing Record 16 of Set 15 | fereydun kenar
# Processing Record 17 of Set 15 | sangar
# Processing Record 18 of Set 15 | redlands
# Processing Record 19 of Set 15 | zhezkazgan
# Processing Record 20 of Set 15 | yongchang
# Processing Record 21 of Set 15 | anori
# Processing Record 22 of Set 15 | itupiranga
# Processing Record 23 of Set 15 | khash
# Processing Record 24 of Set 15 | mukhtolovo
# Processing Record 25 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 26 of Set 15 | druzhba
# Processing Record 27 of Set 15 | brewster
# Processing Record 28 of Set 15 | shingu
# Processing Record 29 of Set 15 | ayan
# Processing Record 30 of Set 15 | port-cartier
# Processing Record 31 of Set 15 | kibala
# Processing Record 32 of Set 15 | freeport
# Processing Record 33 of Set 15 | merke
# Processing Record 34 of Set 15 | dongsheng
# Processing Record 35 of Set 15 | robertsport
# Processing Record 36 of Set 15 | vyselki
# Processing Record 37 of Set 15 | shkotovo-22
# City not found. Skipping...
# Processing Record 38 of Set 15 | horsham
# Processing Record 39 of Set 15 | chaohu
# Processing Record 40 of Set 15 | timra
# Processing Record 41 of Set 15 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 42 of Set 15 | maine-soroa
# Processing Record 43 of Set 15 | lokoja
# Processing Record 44 of Set 15 | zinder
# Processing Record 45 of Set 15 | vila
# Processing Record 46 of Set 15 | ouadda
# Processing Record 47 of Set 15 | masyaf
# Processing Record 48 of Set 15 | salinas
# Processing Record 49 of Set 15 | pontianak
# Processing Record 50 of Set 15 | lhokseumawe
# Processing Record 1 of Set 16 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 16 | saint-georges
# Processing Record 3 of Set 16 | puerto cabello
# Processing Record 4 of Set 16 | rocha
# Processing Record 5 of Set 16 | baker city
# Processing Record 6 of Set 16 | anadyr
# Processing Record 7 of Set 16 | nuuk
# Processing Record 8 of Set 16 | ndungu
# Processing Record 9 of Set 16 | bereda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kavieng      PG  -2.5744  150.7967     83.44        73          60
# 1    Provideniya      RU  64.3833 -173.3000     48.36        81         100
# 2         Himare      AL  40.1017   19.7447     74.08        69           0
# 3  Moose Factory      CA  51.2585  -80.6094     69.80        64           0
# 4      Kununurra      AU -15.7667  128.7333     67.98        94           2
# 5     Georgetown      MY   5.4112  100.3354     78.73        95          20
# 6    East London      ZA -33.0153   27.9116     63.00        87          21
# 7        Vizinga      RU  61.0749   50.1031     40.30        98         100
# 8      Cape Town      ZA -33.9258   18.4232     58.91        86           0
# 9   Saint George      US  37.1041 -113.5841    107.44        16           0
#
#    Wind Speed Current Description
# 0       12.55       broken clouds
# 1       13.42     overcast clouds
# 2        3.02           clear sky
# 3        8.05           clear sky
# 4        0.00           clear sky
# 5        2.30          few clouds
# 6       10.80          few clouds
# 7        7.38     overcast clouds
# 8       12.66           clear sky
# 9       10.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
